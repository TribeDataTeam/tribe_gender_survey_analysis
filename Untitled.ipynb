# %%
pip install numpy
# Out:
# ...
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.6 MB 1.3 MB/s eta 0:00:10
#     --------------------------------------- 0.2/11.6 MB 3.6 MB/s eta 0:00:04
#    -- ------------------------------------- 0.6/11.6 MB 5.4 MB/s eta 0:00:03
#    --- ------------------------------------ 1.1/11.6 MB 6.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.6/11.6 MB 7.7 MB/s eta 0:00:02
#    ------- -------------------------------- 2.1/11.6 MB 8.3 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/11.6 MB 8.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 3.1/11.6 MB 9.0 MB/s eta 0:00:01
#    ------------ --------------------------- 3.6/11.6 MB 8.9 MB/s eta 0:00:01
#    -------------- ------------------------- 4.1/11.6 MB 9.1 MB/s eta 0:00:01
# ...

# %%
pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.9.0-cp311-cp311-win_amd64.whl.metadata (11 kB)
# ...
#   Using cached contourpy-1.2.1-cp311-cp311-win_amd64.whl.metadata (5.8 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached fonttools-4.53.0-cp311-cp311-win_amd64.whl.metadata (165 kB)
# ...
#   Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# ...
#   Using cached pillow-10.3.0-cp311-cp311-win_amd64.whl.metadata (9.4 kB)
# ...
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# ...
# Using cached matplotlib-3.9.0-cp311-cp311-win_amd64.whl (8.0 MB)
# Using cached contourpy-1.2.1-cp311-cp311-win_amd64.whl (188 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.53.0-cp311-cp311-win_amd64.whl (2.2 MB)
# Using cached kiwisolver-1.4.5-cp311-cp311-win_amd64.whl (56 kB)
# Using cached pillow-10.3.0-cp311-cp311-win_amd64.whl (2.5 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# ...

# %%
data_01 = pd.read_csv(r'C:\Users\Djibril-PC\Documents\Tribe_data_team_projects')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data_01 = pd.read_csv(r'C:\Users\Djibril-PC\Documents\Tribe_data_team_projects')
#
# File ~\anaconda3\envs\My_python\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
file_path = 'C:\\Users\\Djibril-PC\\Documents\\Tribe_data_team_projects\\Event_Feedback_Survey.csv'

my_data = pd.read_csv(file_path)

# %%
my_data
# Out:
#   Event Feedback Survey Unnamed: 1  \
# 0    Incoming responses        NaN
# 1                  Name     Status
# 2  Incoming form answer     Female
# 3  Incoming form answer       Male
# 4  Incoming form answer       Male
# 5  Incoming form answer       Male
# 6  Incoming form answer       Male
# 7  Incoming form answer     Female
# 8                   NaN        NaN
#
#                                           Unnamed: 2  \
# 0                                                NaN
# 1  Have you previously attended any events organi...
# 2                                                Yes
# 3                                                Yes
# 4                                                 No
# 5                                                 No
# 6                                                Yes
# 7                                                Yes
# 8                                                NaN
#
#                                           Unnamed: 3  \
# ...

# %%
my_data.describe()
# Out:
#        Event Feedback Survey Unnamed: 1 Unnamed: 2  \
# count                      8          7          7
# unique                     3          3          3
# top     Incoming form answer       Male        Yes
# freq                       6          4          4
#
#                                                Unnamed: 3  \
# count                                                   7
# unique                                                  7
# top     What day of the week are most convenient for y...
# freq                                                    1
#
#                                                Unnamed: 4  \
# count                                                   7
# unique                                                  7
# top     During which time(s) of the day are you most l...
# freq                                                    1
#
#                                                Unnamed: 5 Unnamed: 6  \
# ...
